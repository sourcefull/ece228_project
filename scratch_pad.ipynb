# %%
# !python all.py -train -use_training_data
# Out:
# Using TensorFlow backend.
# You chose to train a new model...
# all.py:123: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   image = scipy.misc.imread( file_name)
# all.py:130: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   image = scipy.misc.imresize(   image, [HEIGHT, WIDTH ]) / 255 #resize and normalization simple
# processed images count  0
# processed images count  1000
# processed images count  2000
# processed images count  3000
# processed images count  4000
# processed images count  5000
# processed images count  6000
# processed images count  7000
# processed images count  8000
# processed images count  9000
# processed images count  10000
# processed images count  11000
# processed images count  12000
# processed images count  13000
# ...
